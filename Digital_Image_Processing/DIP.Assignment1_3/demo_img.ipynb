# %% [markdown]
# <h1>Import library in Python</h1>

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from filter import *
from histogram import *

# %% [markdown]
# <h2>Func1: Read, Save, Show img Lena.png</h2>

# %%
# !python ./run_img.py --input=C:/Users/Administrator/Documents/Nam4_Ki1/Digital_Image_Processing/DIP.Assignment/input/Lena.png --convert_RGB=1 --case=0

# %%
# Show img
img = cv2.imread('C:/Users/Administrator/Documents/Nam4_Ki1/Digital_Image_Processing/DIP.Assignment/output/Lena_output.png')

# Also cv use image is GBR and reverse matplot use RBG
imgplot = plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# <h2>Func4: Use mask to reduce noise, smoothing, and sharp</h2>

# %% [markdown]
# Use Median filter to reduce noise : Filter 3x3 and 5x5.

# %%
# !python ./run_img.py --input=C:/Users/Administrator/Documents/Nam4_Ki1/Digital_Image_Processing/DIP.Assignment/input/Median.jpg --convert_RGB=0 --case=4

# %%
# Show img use median 3x3
img_3x3 = cv2.imread('C:/Users/Administrator/Documents/Nam4_Ki1/Digital_Image_Processing/DIP.Assignment/output/Median_median3x3.png', 0)
img_5x5 = cv2.imread('C:/Users/Administrator/Documents/Nam4_Ki1/Digital_Image_Processing/DIP.Assignment/output/Median_median5x5.png', 0)
imgplot3x3 = cv2.cvtColor(img_3x3, cv2.COLOR_BGR2RGB)
imgplot5x5 = cv2.cvtColor(img_5x5, cv2.COLOR_BGR2RGB)

# Create rows and cols -> Create matrix image. 
# create figure
fig = plt.figure(figsize=(10, 10))
rows = 1
cols = 2
# Adds a subplot at the 1st position
fig.add_subplot(rows, cols, 1)
  
# showing image
plt.imshow(imgplot3x3)
plt.axis('off')
plt.title("Use filter MEDIAN 3X3")
  
# Adds a subplot at the 2nd position
fig.add_subplot(rows, cols, 2)
  
# showing image
plt.imshow(imgplot5x5)
plt.axis('off')
plt.title("Use filter MEDIAN 5x5")
# Out:
# Text(0.5, 1.0, 'Use filter MEDIAN 5x5')

# %% [markdown]
# Use mean filter to smoothing image

# %%
# !python ./run_img.py --input=C:/Users/Administrator/Documents/Nam4_Ki1/Digital_Image_Processing/DIP.Assignment/input/Lena.png --convert_RGB=1 --case=5

# %%
# Show img use median 3x3
img_3x3 = cv2.imread('C:/Users/Administrator/Documents/Nam4_Ki1/Digital_Image_Processing/DIP.Assignment/output/Lena_mean3x3.png', 1)
img_5x5 = cv2.imread('C:/Users/Administrator/Documents/Nam4_Ki1/Digital_Image_Processing/DIP.Assignment/output/Lena_mean5x5.png', 1)
imgplot3x3 = cv2.cvtColor(img_3x3, cv2.COLOR_BGR2RGB)
imgplot5x5 = cv2.cvtColor(img_5x5, cv2.COLOR_BGR2RGB)

# Create rows and cols -> Create matrix image. 
# create figure
fig = plt.figure(figsize=(10, 10))
rows = 1
cols = 2
# Adds a subplot at the 1st position
fig.add_subplot(rows, cols, 1)
  
# showing image
plt.imshow(imgplot3x3)
plt.axis('off')
plt.title("Use filter MEAN 3X3")
  
# Adds a subplot at the 2nd position
fig.add_subplot(rows, cols, 2)
  
# showing image
plt.imshow(imgplot5x5)
plt.axis('off')
plt.title("Use filter MEAN 5x5")
# Out:
# Text(0.5, 1.0, 'Use filter MEAN 5x5')

# %% [markdown]
# Use filter Laplacian to sharp object edge

# %%
# !python ./run_img.py --input=C:/Users/Administrator/Documents/Nam4_Ki1/Digital_Image_Processing/DIP.Assignment/input/Sharpen.png --convert_RGB=0 --case=6
